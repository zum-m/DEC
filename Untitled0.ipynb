# %% [markdown]
# <a href="https://colab.research.google.com/github/zum-m/DEC/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/Shareddrives/dec_phase03/02_assignment/23_三浦一眞/00mydataset/Cheapestelectriccars-EVDatabase.csv')

# %%
df
# Out:
#                                     Name  ... PriceinUK
# 0                         Opel Ampera-e   ...       NaN
# 1              Renault Kangoo Maxi ZE 33  ...   £31,680
# 2                           Nissan Leaf   ...   £25,995
# 3       Audi e-tron Sportback 55 quattro  ...   £79,900
# 4                 Porsche Taycan Turbo S  ...  £138,830
# ..                                   ...  ...       ...
# 175                         MG Marvel R   ...       NaN
# 176  Tesla Model 3 Long Range Dual Motor  ...       NaN
# 177                 MG MG5 EV Long Range  ...   £26,495
# 178            Audi Q4 e-tron 45 quattro  ...       NaN
# 179          Audi Q4 Sportback e-tron 40  ...       NaN
#
# [180 rows x 11 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                                     Name  ... PriceinUK
# 0                         Opel Ampera-e   ...       NaN
# 1              Renault Kangoo Maxi ZE 33  ...   £31,680
# 2                           Nissan Leaf   ...   £25,995
# 3       Audi e-tron Sportback 55 quattro  ...   £79,900
# 4                 Porsche Taycan Turbo S  ...  £138,830
# ..                                   ...  ...       ...
# 175                         MG Marvel R   ...       NaN
# 176  Tesla Model 3 Long Range Dual Motor  ...       NaN
# 177                 MG MG5 EV Long Range  ...   £26,495
# 178            Audi Q4 e-tron 45 quattro  ...       NaN
# 179          Audi Q4 Sportback e-tron 40  ...       NaN
#
# [180 rows x 11 columns]>

# %%
# 行数、桁数の表示を設定する
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
# 小数点以下の桁数の設定
pd.set_option('display.float_format', '{:.3f}'.format)
# 不要な警告の表示を省略する
import warnings  
warnings.filterwarnings('ignore')

# %%
df
# Out:
#                                        Name  \
# 0                            Opel Ampera-e
# 1                 Renault Kangoo Maxi ZE 33
# 2                              Nissan Leaf
# 3          Audi e-tron Sportback 55 quattro
# 4                    Porsche Taycan Turbo S
# 5                    Nissan e-NV200 Evalia
# 6          Volkswagen ID.3 Pure Performance
# 7                                  BMW iX3
# 8                            Nissan Leaf e+
# 9                             BMW i3 120 Ah
# 10                         Mercedes EQA 250
# 11                   DS 3 Crossback E-Tense
# 12                           BMW i3s 120 Ah
# 13                               Sono Sion
# 14                        Audi e-tron GT RS
# 15                        Kia e-Soul 64 kWh
# 16                    Renault Zoe ZE50 R110
# 17                   Hyundai IONIQ Electric
# 18                           Lightyear One
# 19                          Tesla Roadster
# ...

# %%
df.shape
# Out:
# (180, 11)
